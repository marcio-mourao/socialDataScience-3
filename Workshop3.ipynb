# %% [markdown]
# # <center> DATA SCIENCE WITH SOCIAL SCIENCE DATA <br/><br/> CSCAR WORKSHOP <br/><br/> 03/30/2017
# ## <center> Marcio Mourao and Jeff Lockhart

# %% [markdown]
# # <center> Setup for Anaconda / Jupyter Notebook
#
# <ul>
#     <li>Get the materials:</li>
#     <ul>
#         <li>Go to the page https://marcio-mourao.github.io/</li>
#         <li>Download the materials to your "username/Documents"</li>
#     </ul><br/>
#     <li>Open the Jupyter Notebook:</li>
#     <ul>
#         <li>Click the Windows button (Bottom Left Corner)</li>
#         <li>Click "All apps"</li>
#         <li>Click "Anaconda3 (64-bit)"</li>
#         <li>Click "Jupyter Notebook" </li>
#     </ul><br/>
#     <li>Click "Workshop.ipynb" (this should open a new tab in the browser)</li>
# </ul>

# %% [markdown]
# # <center> Introduction
#
# <ul>
#   <li>Please, sign up the sheet! </li>
#   <li>Don't forget to go to: http://cscar.research.umich.edu/ to know what we're offering!</li>
# </ul>

# %% [markdown]
# # <center> Summary of this workshop
#
# <ul>
#   <li>Pandas Dataframes</li>
#   <li>Matplotlib</li>
#   <li>Statsmodel</li>
# </ul>

# %% [markdown]
# # <center> References
#
# <ul>
#   <li>An Introduction to Statistical Learning (Springer)</li>
#   <li>https://www.continuum.io/anaconda-overview</li>
#   <li>http://www.numpy.org/</li>
#   <li>http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html</li>
#   <li>http://matplotlib.org/</li>
#   <li>http://pandas.pydata.org/pandas-docs/stable/10min.html</li>
#   <li>http://scikit-learn.org/stable/</li>
#   <li>http://statsmodels.sourceforge.net/</li>
# </ul>

# %%
#Check Python version
import sys
print(sys.version)
# Out:
# 3.5.3 |Anaconda custom (x86_64)| (default, Mar  6 2017, 12:15:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %% [markdown]
# ## Import relevant modules

# %%
# %matplotlib inline
import numpy as np
#from numpy import * #another way of importing but I prefer the above
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
#Check numpy and pandas version
print(np.__version__)
print(pd.__version__)
# Out:
# 1.12.1
# 0.19.2

# %% [markdown]
# ## Python Simple Data Types
# ##### Integers
# ##### Floats
# ##### Strings
# ##### Booleans

# %% [markdown]
# ## Python Data Structures

# %% [markdown]
# ### Lists

# %%
example_list = [2,4,'fg',8,[3,4]]
print(example_list)
print(example_list[0])
print(example_list[2:4])
print(example_list[-2])
example_list[2]=20
print(example_list)
print(example_list[4][0])
# Out:
# [2, 4, 'fg', 8, [3, 4]]
# 2
# ['fg', 8]
# 8
# [2, 4, 20, 8, [3, 4]]
# 3

# %% [markdown]
# ### Tuples

# %%
example_tuple = (2,4,6,8,10)
print(example_tuple)
print(example_tuple[1])
#example_tuple[2]=20 #this should produce an error
# Out:
# (2, 4, 6, 8, 10)
# 4

# %% [markdown]
# ### Dictionary

# %%
example_dictionary = {'A':20,'B':40,'C':60}
print(example_dictionary)
print(example_dictionary['B'])
example_dictionary['C']=100
print(example_dictionary)
print(example_dictionary.keys())
print(example_dictionary.values())
# Out:
# {'B': 40, 'C': 60, 'A': 20}
# 40
# {'B': 40, 'C': 100, 'A': 20}
# dict_keys(['B', 'C', 'A'])
# dict_values([40, 100, 20])

# %% [markdown]
# ### Numpy arrays

# %%
example_array = np.array([2,4,6,8,10])
print(example_array)
print(example_array[0])
print(example_array[2:4])
print(example_array[-2])
example_array[2]=20
print(example_array)
# Out:
# [ 2  4  6  8 10]
# 2
# [6 8]
# 8
# [ 2  4 20  8 10]

# %% [markdown]
# ### Pandas Series, a one dimensional labeled array

# %%
example_series = pd.Series(example_dictionary)
print(example_series)
print(example_series[0])
print(example_series['B':])
# Out:
# A     20
# B     40
# C    100
# dtype: int64
# 20
# B     40
# C    100
# dtype: int64

# %% [markdown]
# ### Pandas Dataframes, a two-dimensional labeled data structure with columns of potentially different types

# %%
d=[['df',1.0],
   ['as',3],
   ['bq',5]]
example_series = pd.DataFrame(d,index=['Row1','Row2','Row3'],columns=['Column1','Column2'])
print(example_series)
example_series.dtypes
# Out:
#      Column1  Column2
# Row1      df      1.0
# Row2      as      3.0
# Row3      bq      5.0
# Column1     object
# Column2    float64
# dtype: object

# %% [markdown]
# # <center> Lets work on the data

# %% [markdown]
# ## Create, describe and look for missing data

# %%
#Displays the signature of the function
# ?pd.read_csv

# %%
#Creates a dataframe named "advertising" with columns 'TV' and 'Radio'
col_names=['TV','Radio']
advertising = pd.read_csv('Advertising.csv',header='infer',usecols=col_names)
advertising
# Out:
#         TV Radio
# 0    230.1     .
# 1     44.5  39.3
# 2     17.2  45.9
# 3    151.5  41.3
# 4      NaN  10.8
# 5      8.7  48.9
# 6     57.5  32.8
# 7    120.2  19.6
# 8      8.6   2.1
# 9    199.8   2.6
# 10    66.1   5.8
# 11   214.7    24
# 12    23.8  35.1
# 13    97.5   7.6
# 14   204.1  32.9
# 15   195.4  47.7
# 16    67.8  36.6
# 17   281.4  39.6
# 18    69.2  20.5
# 19   147.3  23.9
# 20   218.4  27.7
# 21   237.4   5.1
# 22    13.2  15.9
# 23   228.3  16.9
# 24    62.3  12.6
# 25   262.9   3.5
# 26   142.9  29.3
# 27   240.1  16.7
# 28   248.8  27.1
# 29    70.6    16
# ..     ...   ...
# 170   50.0  11.6
# 171  164.5  20.9
# 172   19.6  20.1
# 173  168.4   7.1
# 174  222.4   3.4
# 175  276.9  48.9
# 176  248.4  30.2
# 177  170.2   7.8
# 178  276.7   2.3
# 179  165.6    10
# 180  156.6   2.6
# 181  218.5   5.4
# 182   56.2   5.7
# 183  287.6    43
# 184  253.8  21.3
# 185  205.0  45.1
# 186  139.5   2.1
# 187  191.1  28.7
# 188  286.0  13.9
# 189   18.7  12.1
# 190   39.5  41.1
# 191   75.5  10.8
# 192   17.2   4.1
# 193  166.8    42
# 194  149.7  35.6
# 195   38.2   3.7
# 196   94.2   4.9
# 197  177.0   9.3
# 198  283.6    42
# 199  232.1   8.6
#
# [200 rows x 2 columns]

# %%
#Displays number of lines and number of columns of the dataframe
advertising.shape
# Out:
# (200, 2)

# %%
#Displays the data types associated with each dataframe column
advertising.dtypes
# Out:
# TV       float64
# Radio     object
# dtype: object

# %%
#Read all columns from the data into a new dataframe - we will give it the same name
advertising = pd.read_csv('Advertising.csv',index_col=0)
advertising
# Out:
#         TV Radio  Newspaper Sales
# 1    230.1     .       69.2  22.1
# 2     44.5  39.3       45.1  10.4
# 3     17.2  45.9        NaN   9.3
# 4    151.5  41.3       58.5  18.5
# 5      NaN  10.8       58.4  12.9
# 6      8.7  48.9       75.0   7.2
# 7     57.5  32.8       23.5  11.8
# 8    120.2  19.6       11.6  13.2
# 9      8.6   2.1        1.0   4.8
# 10   199.8   2.6       21.2  10.6
# 11    66.1   5.8       24.2   8.6
# 12   214.7    24        4.0  17.4
# 13    23.8  35.1       65.9   9.2
# 14    97.5   7.6        7.2   9.7
# 15   204.1  32.9       46.0    19
# 16   195.4  47.7       52.9  22.4
# 17    67.8  36.6      114.0  12.5
# 18   281.4  39.6       55.8  24.4
# 19    69.2  20.5       18.3  11.3
# 20   147.3  23.9       19.1  14.6
# 21   218.4  27.7       53.4    18
# 22   237.4   5.1       23.5  12.5
# 23    13.2  15.9       49.6   5.6
# 24   228.3  16.9        NaN  15.5
# 25    62.3  12.6       18.3   9.7
# 26   262.9   3.5       19.5    12
# 27   142.9  29.3       12.6    15
# 28   240.1  16.7       22.9  15.9
# 29   248.8  27.1       22.9  18.9
# 30    70.6    16       40.8  10.5
# ..     ...   ...        ...   ...
# 171   50.0  11.6       18.4   8.4
# 172  164.5  20.9       47.4  14.5
# 173   19.6  20.1       17.0   7.6
# 174  168.4   7.1       12.8  11.7
# 175  222.4   3.4       13.1  11.5
# 176  276.9  48.9       41.8    27
# 177  248.4  30.2       20.3  20.2
# 178  170.2   7.8       35.2  11.7
# 179  276.7   2.3       23.7  11.8
# 180  165.6    10       17.6     #
# 181  156.6   2.6        8.3  10.5
# 182  218.5   5.4       27.4  12.2
# 183   56.2   5.7       29.7   8.7
# 184  287.6    43       71.8  26.2
# 185  253.8  21.3       30.0  17.6
# 186  205.0  45.1       19.6  22.6
# 187  139.5   2.1       26.6  10.3
# 188  191.1  28.7       18.2  17.3
# 189  286.0  13.9        3.7  15.9
# 190   18.7  12.1       23.4   6.7
# 191   39.5  41.1        5.8  10.8
# 192   75.5  10.8        6.0   9.9
# 193   17.2   4.1       31.6   5.9
# 194  166.8    42        3.6  19.6
# 195  149.7  35.6        6.0  17.3
# 196   38.2   3.7       13.8   7.6
# 197   94.2   4.9        8.1   9.7
# 198  177.0   9.3        6.4  12.8
# 199  283.6    42       66.2  25.5
# 200  232.1   8.6        NaN  13.4
#
# [200 rows x 4 columns]

# %%
#Displays the data types of each column on the dataframe
advertising.dtypes
# Out:
# TV           float64
# Radio         object
# Newspaper    float64
# Sales         object
# dtype: object

# %%
#Describes the dataframe
advertising.describe(include='all')
# Out:
#                 TV Radio   Newspaper Sales
# count   195.000000   200  195.000000   200
# unique         NaN   163         NaN   120
# top            NaN     .         NaN   9.7
# freq           NaN     5         NaN     5
# mean    146.454359   NaN   30.437436   NaN
# std      86.070947   NaN   21.815987   NaN
# min       0.700000   NaN    0.300000   NaN
# 25%      72.000000   NaN   12.700000   NaN
# 50%     149.700000   NaN   25.600000   NaN
# 75%     219.150000   NaN   45.100000   NaN
# max     296.400000   NaN  114.000000   NaN

# %%
#Gets frequency distribution
advertising['Radio'].value_counts().head()
# Out:
# .       5
# 4.1     3
# 5.7     3
# 26.7    2
# 2.6     2
# Name: Radio, dtype: int64

# %%
#Displays whether columns contain any null values
advertising.isnull().any(axis=0)
# Out:
# TV            True
# Radio        False
# Newspaper     True
# Sales        False
# dtype: bool

# %%
#Creates a list with indexes where you have nulls
null_indexes=np.where(advertising.isnull())
null_indexes
# Out:
# (array([  2,   4,  23,  30,  53,  81, 117, 143, 164, 199]),
#  array([2, 0, 2, 0, 0, 2, 0, 2, 0, 2]))

# %%
#Displays the lines of the dataframe with the null indexes
advertising.iloc[null_indexes[0]]
# Out:
#         TV Radio  Newspaper Sales
# 3     17.2  45.9        NaN   9.3
# 5      NaN  10.8       58.4  12.9
# 24   228.3  16.9        NaN  15.5
# 31     NaN  28.3       43.2     #
# 54     NaN  46.2       58.7  21.2
# 82   239.8   4.1        NaN  12.3
# 118    NaN   0.8       14.8   9.4
# 144  104.6   5.7        NaN  10.4
# 165    NaN  14.7        5.4  11.9
# 200  232.1   8.6        NaN  13.4

# %%
#Count the number of missing values in each column of the dataframe
advertising.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# TV           5
# Radio        0
# Newspaper    5
# Sales        0
# dtype: int64

# %% [markdown]
# ## Indexing and Slicing

# %%
#Creates a dataframe named "advertising" and explictly adds other characters to be interpreted as missing values
advertising = pd.read_csv('Advertising.csv', index_col=0, na_values=['.','#'])
advertising
# Out:
#         TV  Radio  Newspaper  Sales
# 1    230.1    NaN       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9        NaN    9.3
# 4    151.5   41.3       58.5   18.5
# 5      NaN   10.8       58.4   12.9
# 6      8.7   48.9       75.0    7.2
# 7     57.5   32.8       23.5   11.8
# 8    120.2   19.6       11.6   13.2
# 9      8.6    2.1        1.0    4.8
# 10   199.8    2.6       21.2   10.6
# 11    66.1    5.8       24.2    8.6
# 12   214.7   24.0        4.0   17.4
# 13    23.8   35.1       65.9    9.2
# 14    97.5    7.6        7.2    9.7
# 15   204.1   32.9       46.0   19.0
# 16   195.4   47.7       52.9   22.4
# 17    67.8   36.6      114.0   12.5
# 18   281.4   39.6       55.8   24.4
# 19    69.2   20.5       18.3   11.3
# 20   147.3   23.9       19.1   14.6
# 21   218.4   27.7       53.4   18.0
# 22   237.4    5.1       23.5   12.5
# 23    13.2   15.9       49.6    5.6
# 24   228.3   16.9        NaN   15.5
# 25    62.3   12.6       18.3    9.7
# 26   262.9    3.5       19.5   12.0
# 27   142.9   29.3       12.6   15.0
# 28   240.1   16.7       22.9   15.9
# 29   248.8   27.1       22.9   18.9
# 30    70.6   16.0       40.8   10.5
# ..     ...    ...        ...    ...
# 171   50.0   11.6       18.4    8.4
# 172  164.5   20.9       47.4   14.5
# 173   19.6   20.1       17.0    7.6
# 174  168.4    7.1       12.8   11.7
# 175  222.4    3.4       13.1   11.5
# 176  276.9   48.9       41.8   27.0
# 177  248.4   30.2       20.3   20.2
# 178  170.2    7.8       35.2   11.7
# 179  276.7    2.3       23.7   11.8
# 180  165.6   10.0       17.6    NaN
# 181  156.6    2.6        8.3   10.5
# 182  218.5    5.4       27.4   12.2
# 183   56.2    5.7       29.7    8.7
# 184  287.6   43.0       71.8   26.2
# 185  253.8   21.3       30.0   17.6
# 186  205.0   45.1       19.6   22.6
# 187  139.5    2.1       26.6   10.3
# 188  191.1   28.7       18.2   17.3
# 189  286.0   13.9        3.7   15.9
# 190   18.7   12.1       23.4    6.7
# 191   39.5   41.1        5.8   10.8
# 192   75.5   10.8        6.0    9.9
# 193   17.2    4.1       31.6    5.9
# 194  166.8   42.0        3.6   19.6
# 195  149.7   35.6        6.0   17.3
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        NaN   13.4
#
# [200 rows x 4 columns]

# %%
#Displays the data types of columns on the dataframe
advertising.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
#Describes the dataframe
advertising.describe(include='all')
# Out:
#                TV       Radio   Newspaper       Sales
# count  195.000000  195.000000  195.000000  195.000000
# mean   146.454359   22.982051   30.437436   13.957949
# std     86.070947   14.884775   21.815987    5.193521
# min      0.700000    0.000000    0.300000    1.600000
# 25%     72.000000    9.750000   12.700000   10.350000
# 50%    149.700000   22.300000   25.600000   12.900000
# 75%    219.150000   36.050000   45.100000   17.350000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#Displays the first rows of the dataframe
advertising[:5]
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1    NaN       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9        NaN    9.3
# 4  151.5   41.3       58.5   18.5
# 5    NaN   10.8       58.4   12.9

# %%
#Displays the first rows of the dataframe
advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1    NaN       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9        NaN    9.3
# 4  151.5   41.3       58.5   18.5
# 5    NaN   10.8       58.4   12.9

# %%
#Displays the last rows of the dataframe
advertising[::-1].head()
# Out:
#         TV  Radio  Newspaper  Sales
# 200  232.1    8.6        NaN   13.4
# 199  283.6   42.0       66.2   25.5
# 198  177.0    9.3        6.4   12.8
# 197   94.2    4.9        8.1    9.7
# 196   38.2    3.7       13.8    7.6

# %%
#Same as above, but returns a numpy array of values
advertising[::-1].head().values
# Out:
# array([[ 232.1,    8.6,    nan,   13.4],
#        [ 283.6,   42. ,   66.2,   25.5],
#        [ 177. ,    9.3,    6.4,   12.8],
#        [  94.2,    4.9,    8.1,    9.7],
#        [  38.2,    3.7,   13.8,    7.6]])

# %%
#From the dataframe, retrive rows in position (integer based index) 2 and 3 and columns in location 0
advertising.iloc[2:4,0]
# Out:
# 3     17.2
# 4    151.5
# Name: TV, dtype: float64

# %%
#From the dataframe, retrieve rows with labels 2, 3 and 4 and column 'TV'
advertising.loc[2:4,'TV']
# Out:
# 2     44.5
# 3     17.2
# 4    151.5
# Name: TV, dtype: float64

# %%
#From the dataframe, retrive rows with labels 2, 3 and 4 and columns 'TV' and 'Sales'
advertising.ix[2:4,['TV','Sales']]
#advertising.ix[2:4,[0,3]] #Another way of getting the slice, but I prefer the above
# Out:
#       TV  Sales
# 2   44.5   10.4
# 3   17.2    9.3
# 4  151.5   18.5

# %%
#Retrieves a boolean series with True values wherever sales is lower than 10
advertising['Sales']<10
# Out:
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9       True
# 10     False
# 11      True
# 12     False
# 13      True
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23      True
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
#        ...
# 171     True
# 172    False
# 173     True
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183     True
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190     True
# 191    False
# 192     True
# 193     True
# 194    False
# 195    False
# 196     True
# 197     True
# 198    False
# 199    False
# 200    False
# Name: Sales, dtype: bool

# %%
#Returns a subsection of the dataframe where sales are lower than 10
advertising.ix[advertising['Sales']<10,:]
# Out:
#        TV  Radio  Newspaper  Sales
# 3    17.2   45.9        NaN    9.3
# 6     8.7   48.9       75.0    7.2
# 9     8.6    2.1        1.0    4.8
# 11   66.1    5.8       24.2    8.6
# 13   23.8   35.1       65.9    9.2
# 14   97.5    7.6        7.2    9.7
# 23   13.2   15.9       49.6    5.6
# 25   62.3   12.6       18.3    9.7
# 33   97.2    1.5       30.0    9.6
# 35   95.7    1.4        7.4    9.5
# 45   25.1   25.7       43.3    8.5
# 50   66.9   11.7       36.8    9.7
# 57    7.3   28.1       41.4    5.5
# 61   53.5    2.0       21.4    8.1
# 66   69.0    9.3        0.9    9.3
# 67   31.5   24.6        2.2    9.5
# 76   16.9   43.7       89.4    8.7
# 77   27.5    1.6       20.7    6.9
# 79    5.4   29.9        9.4    5.3
# 92   28.6    1.5       33.0    7.3
# 107  25.0   11.0       29.7    7.2
# 108  90.4    0.3       23.2    8.7
# 109  13.1    0.4       25.6    5.3
# 118   NaN    0.8       14.8    9.4
# 120  19.4   16.0       22.3    6.6
# 122  18.8   21.7       50.4    7.0
# 127   7.8   38.9       50.6    6.6
# 128  80.2    0.0        9.2    8.8
# 130  59.6   12.0       43.1    9.7
# 131   0.7   39.6        8.7    1.6
# 133   8.4   27.2        2.1    5.7
# 137  25.6   39.0        9.3    9.5
# 139  43.0   25.9       20.5    9.6
# 156   4.1   11.6        5.7    3.2
# 159  11.7   36.9       45.2    7.3
# 167  17.9   37.6       21.6    8.0
# 171  50.0   11.6       18.4    8.4
# 173  19.6   20.1       17.0    7.6
# 183  56.2    5.7       29.7    8.7
# 190  18.7   12.1       23.4    6.7
# 192  75.5   10.8        6.0    9.9
# 193  17.2    4.1       31.6    5.9
# 196  38.2    3.7       13.8    7.6
# 197  94.2    4.9        8.1    9.7

# %%
#Removes any lines from the dataframe that contains NaNs 
advertising2=advertising.dropna(axis=0,how='any')
advertising2
# Out:
#         TV  Radio  Newspaper  Sales
# 2     44.5   39.3       45.1   10.4
# 4    151.5   41.3       58.5   18.5
# 6      8.7   48.9       75.0    7.2
# 7     57.5   32.8       23.5   11.8
# 8    120.2   19.6       11.6   13.2
# 9      8.6    2.1        1.0    4.8
# 10   199.8    2.6       21.2   10.6
# 11    66.1    5.8       24.2    8.6
# 12   214.7   24.0        4.0   17.4
# 13    23.8   35.1       65.9    9.2
# 14    97.5    7.6        7.2    9.7
# 15   204.1   32.9       46.0   19.0
# 16   195.4   47.7       52.9   22.4
# 17    67.8   36.6      114.0   12.5
# 18   281.4   39.6       55.8   24.4
# 19    69.2   20.5       18.3   11.3
# 20   147.3   23.9       19.1   14.6
# 21   218.4   27.7       53.4   18.0
# 22   237.4    5.1       23.5   12.5
# 23    13.2   15.9       49.6    5.6
# 25    62.3   12.6       18.3    9.7
# 26   262.9    3.5       19.5   12.0
# 27   142.9   29.3       12.6   15.0
# 28   240.1   16.7       22.9   15.9
# 29   248.8   27.1       22.9   18.9
# 30    70.6   16.0       40.8   10.5
# 32   112.9   17.4       38.6   11.9
# 33    97.2    1.5       30.0    9.6
# 34   265.6   20.0        0.3   17.4
# 35    95.7    1.4        7.4    9.5
# ..     ...    ...        ...    ...
# 169  215.4   23.6       57.6   17.1
# 170  284.3   10.6        6.4   15.0
# 171   50.0   11.6       18.4    8.4
# 172  164.5   20.9       47.4   14.5
# 173   19.6   20.1       17.0    7.6
# 174  168.4    7.1       12.8   11.7
# 175  222.4    3.4       13.1   11.5
# 176  276.9   48.9       41.8   27.0
# 177  248.4   30.2       20.3   20.2
# 178  170.2    7.8       35.2   11.7
# 179  276.7    2.3       23.7   11.8
# 181  156.6    2.6        8.3   10.5
# 182  218.5    5.4       27.4   12.2
# 183   56.2    5.7       29.7    8.7
# 184  287.6   43.0       71.8   26.2
# 185  253.8   21.3       30.0   17.6
# 186  205.0   45.1       19.6   22.6
# 187  139.5    2.1       26.6   10.3
# 188  191.1   28.7       18.2   17.3
# 189  286.0   13.9        3.7   15.9
# 190   18.7   12.1       23.4    6.7
# 191   39.5   41.1        5.8   10.8
# 192   75.5   10.8        6.0    9.9
# 193   17.2    4.1       31.6    5.9
# 194  166.8   42.0        3.6   19.6
# 195  149.7   35.6        6.0   17.3
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
#
# [181 rows x 4 columns]

# %%
#Checks for NaNs
advertising2.isnull().any()
# Out:
# TV           False
# Radio        False
# Newspaper    False
# Sales        False
# dtype: bool

# %%
#Displays the number of lines and columns of the dataframe
advertising2.shape
# Out:
# (181, 4)

# %%
#Fill the missing data using interpolation
advertising2=advertising.interpolate(method='linear')
advertising2
# Out:
#         TV  Radio  Newspaper  Sales
# 1    230.1    NaN      69.20  22.10
# 2     44.5   39.3      45.10  10.40
# 3     17.2   45.9      51.80   9.30
# 4    151.5   41.3      58.50  18.50
# 5     80.1   10.8      58.40  12.90
# 6      8.7   48.9      75.00   7.20
# 7     57.5   32.8      23.50  11.80
# 8    120.2   19.6      11.60  13.20
# 9      8.6    2.1       1.00   4.80
# 10   199.8    2.6      21.20  10.60
# 11    66.1    5.8      24.20   8.60
# 12   214.7   24.0       4.00  17.40
# 13    23.8   35.1      65.90   9.20
# 14    97.5    7.6       7.20   9.70
# 15   204.1   32.9      46.00  19.00
# 16   195.4   47.7      52.90  22.40
# 17    67.8   36.6     114.00  12.50
# 18   281.4   39.6      55.80  24.40
# 19    69.2   20.5      18.30  11.30
# 20   147.3   23.9      19.10  14.60
# 21   218.4   27.7      53.40  18.00
# 22   237.4    5.1      23.50  12.50
# 23    13.2   15.9      49.60   5.60
# 24   228.3   16.9      33.95  15.50
# 25    62.3   12.6      18.30   9.70
# 26   262.9    3.5      19.50  12.00
# 27   142.9   29.3      12.60  15.00
# 28   240.1   16.7      22.90  15.90
# 29   248.8   27.1      22.90  18.90
# 30    70.6   16.0      40.80  10.50
# ..     ...    ...        ...    ...
# 171   50.0   11.6      18.40   8.40
# 172  164.5   20.9      47.40  14.50
# 173   19.6   20.1      17.00   7.60
# 174  168.4    7.1      12.80  11.70
# 175  222.4    3.4      13.10  11.50
# 176  276.9   48.9      41.80  27.00
# 177  248.4   30.2      20.30  20.20
# 178  170.2    7.8      35.20  11.70
# 179  276.7    2.3      23.70  11.80
# 180  165.6   10.0      17.60  11.15
# 181  156.6    2.6       8.30  10.50
# 182  218.5    5.4      27.40  12.20
# 183   56.2    5.7      29.70   8.70
# 184  287.6   43.0      71.80  26.20
# 185  253.8   21.3      30.00  17.60
# 186  205.0   45.1      19.60  22.60
# 187  139.5    2.1      26.60  10.30
# 188  191.1   28.7      18.20  17.30
# 189  286.0   13.9       3.70  15.90
# 190   18.7   12.1      23.40   6.70
# 191   39.5   41.1       5.80  10.80
# 192   75.5   10.8       6.00   9.90
# 193   17.2    4.1      31.60   5.90
# 194  166.8   42.0       3.60  19.60
# 195  149.7   35.6       6.00  17.30
# 196   38.2    3.7      13.80   7.60
# 197   94.2    4.9       8.10   9.70
# 198  177.0    9.3       6.40  12.80
# 199  283.6   42.0      66.20  25.50
# 200  232.1    8.6      66.20  13.40
#
# [200 rows x 4 columns]

# %%
#Checks for NaNs
advertising2.isnull().any()
# Out:
# TV           False
# Radio         True
# Newspaper    False
# Sales        False
# dtype: bool

# %%
#Displays the number of lines and columns of the dataframe
advertising2.shape
# Out:
# (200, 4)

# %% [markdown]
# ## Apply functions, Groupby and Sort data

# %%
#Creates a dataframe named "advertising" with the original values (no missing values or odd characters)
advertising = pd.read_csv('Advertising_original.csv', index_col=0)
advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
#Displays whether columns contain any null values
advertising.isnull().any()
# Out:
# TV           False
# Radio        False
# Newspaper    False
# Sales        False
# dtype: bool

# %%
#Returns the mean of each one of the numerical columns on the dataframe
advertising.mean(axis=0)
# Out:
# TV           147.0425
# Radio         23.2640
# Newspaper     30.5540
# Sales         14.0225
# dtype: float64

# %%
#Returns the mean of each one of the numerical columns on the dataframe
advertising.apply(np.mean)
# Out:
# TV           147.0425
# Radio         23.2640
# Newspaper     30.5540
# Sales         14.0225
# dtype: float64

# %%
#Returns the cumulative sum along the columns
advertising.loc[:,'Sales':].apply(np.cumsum,axis=0).head()
# Out:
#    Sales
# 1   22.1
# 2   32.5
# 3   41.8
# 4   60.3
# 5   73.2

# %%
#Returns the difference between the max and min for each one of the columns
advertising.apply(lambda x: (x.max()) - x.min())
# Out:
# TV           295.7
# Radio         49.6
# Newspaper    113.7
# Sales         25.4
# dtype: float64

# %%
#Confirms the difference above for the column 'age
advertising.TV.max()-advertising.TV.min()
# Out:
# 295.69999999999999

# %%
#Calculate zscore
from scipy.stats import zscore
advertising2=advertising.apply(zscore)
advertising2
# Out:
#            TV     Radio  Newspaper     Sales
# 1    0.969852  0.981522   1.778945  1.552053
# 2   -1.197376  1.082808   0.669579 -0.696046
# 3   -1.516155  1.528463   1.783549 -0.907406
# 4    0.052050  1.217855   1.286405  0.860330
# 5    0.394182 -0.841614   1.281802 -0.215683
# 6   -1.615408  1.731034   2.045930 -1.310911
# 7   -1.045577  0.643905  -0.324708 -0.427043
# 8   -0.313437 -0.247406  -0.872487 -0.158039
# 9   -1.616576 -1.429069  -1.360424 -1.772059
# 10   0.616043 -1.395307  -0.430582 -0.657617
# 11  -0.945156 -1.179231  -0.292486 -1.041908
# 12   0.790028  0.049697  -1.222329  0.648971
# 13  -1.439088  0.799209   1.627040 -0.926620
# 14  -0.578502 -1.057689  -1.075027 -0.830548
# 15   0.666253  0.650657   0.711007  0.956403
# 16   0.564665  1.650006   1.028627  1.609697
# 17  -0.925305  0.900494   3.841171 -0.292541
# 18   1.568876  1.103065   1.162119  1.993987
# 19  -0.908957 -0.186635  -0.564074 -0.523115
# 20   0.003007  0.042945  -0.527248  0.110964
# 21   0.833233  0.299535   1.051643  0.764258
# 22   1.055093 -1.226498  -0.324708 -0.292541
# 23  -1.562862 -0.497243   0.876722 -1.618343
# 24   0.948834 -0.429720  -0.200423  0.283895
# 25  -0.989528 -0.720071  -0.564074 -0.830548
# 26   1.352854 -1.334536  -0.508836 -0.388614
# 27  -0.048371  0.407572  -0.826455  0.187822
# 28   1.086621 -0.443225  -0.352328  0.360753
# 29   1.188210  0.259020  -0.352328  0.937188
# 30  -0.892610 -0.490491   0.471642 -0.676832
# ..        ...       ...        ...       ...
# 171 -1.133153 -0.787595  -0.559471 -1.080337
# 172  0.203849 -0.159626   0.775452  0.091749
# 173 -1.488130 -0.213645  -0.623915 -1.234053
# 174  0.249389 -1.091451  -0.817249 -0.446257
# 175  0.879940 -1.341288  -0.803439 -0.484686
# 176  1.516330  1.731034   0.517674  2.493565
# 177  1.183539  0.468343  -0.472010  1.186977
# 178  0.270407 -1.044184   0.213864 -0.446257
# 179  1.513995 -1.415564  -0.315502 -0.427043
# 180  0.216694 -0.895633  -0.596296 -0.273327
# 181  0.111602 -1.395307  -1.024392 -0.676832
# 182  0.834400 -1.206241  -0.145184 -0.350185
# 183 -1.060757 -1.185984  -0.039311 -1.022693
# 184  1.641273  1.332645   1.898628  2.339849
# 185  1.246594 -0.132616  -0.025502  0.687400
# 186  0.676763  1.474444  -0.504232  1.648126
# 187 -0.088073 -1.429069  -0.182010 -0.715261
# 188  0.514454  0.367058  -0.568677  0.629756
# 189  1.622590 -0.632291  -1.236138  0.360753
# 190 -1.498640 -0.753833  -0.329312 -1.406983
# 191 -1.255761  1.204350  -1.139472 -0.619188
# 192 -0.835393 -0.841614  -1.130265 -0.792119
# 193 -1.516155 -1.294022   0.048149 -1.560700
# 194  0.230706  1.265121  -1.240742  1.071690
# 195  0.031031  0.832971  -1.130265  0.629756
# 196 -1.270941 -1.321031  -0.771217 -1.234053
# 197 -0.617035 -1.240003  -1.033598 -0.830548
# 198  0.349810 -0.942899  -1.111852 -0.234898
# 199  1.594565  1.265121   1.640850  2.205347
# 200  0.993206 -0.990165  -1.005979 -0.119610
#
# [200 rows x 4 columns]

# %%
#Obtains the mean of each column
advertising2.mean()
# Out:
# TV           1.104672e-16
# Radio       -4.413137e-16
# Newspaper    2.220446e-16
# Sales       -2.148975e-16
# dtype: float64

# %%
#Creates a new column on the dataframe with a 
advertising['marketType']='B15'
advertising.loc[advertising.Sales>15,'marketType']='G15'
advertising
# Out:
#         TV  Radio  Newspaper  Sales marketType
# 1    230.1   37.8       69.2   22.1        G15
# 2     44.5   39.3       45.1   10.4        B15
# 3     17.2   45.9       69.3    9.3        B15
# 4    151.5   41.3       58.5   18.5        G15
# 5    180.8   10.8       58.4   12.9        B15
# 6      8.7   48.9       75.0    7.2        B15
# 7     57.5   32.8       23.5   11.8        B15
# 8    120.2   19.6       11.6   13.2        B15
# 9      8.6    2.1        1.0    4.8        B15
# 10   199.8    2.6       21.2   10.6        B15
# 11    66.1    5.8       24.2    8.6        B15
# 12   214.7   24.0        4.0   17.4        G15
# 13    23.8   35.1       65.9    9.2        B15
# 14    97.5    7.6        7.2    9.7        B15
# 15   204.1   32.9       46.0   19.0        G15
# 16   195.4   47.7       52.9   22.4        G15
# 17    67.8   36.6      114.0   12.5        B15
# 18   281.4   39.6       55.8   24.4        G15
# 19    69.2   20.5       18.3   11.3        B15
# 20   147.3   23.9       19.1   14.6        B15
# 21   218.4   27.7       53.4   18.0        G15
# 22   237.4    5.1       23.5   12.5        B15
# 23    13.2   15.9       49.6    5.6        B15
# 24   228.3   16.9       26.2   15.5        G15
# 25    62.3   12.6       18.3    9.7        B15
# 26   262.9    3.5       19.5   12.0        B15
# 27   142.9   29.3       12.6   15.0        B15
# 28   240.1   16.7       22.9   15.9        G15
# 29   248.8   27.1       22.9   18.9        G15
# 30    70.6   16.0       40.8   10.5        B15
# ..     ...    ...        ...    ...        ...
# 171   50.0   11.6       18.4    8.4        B15
# 172  164.5   20.9       47.4   14.5        B15
# 173   19.6   20.1       17.0    7.6        B15
# 174  168.4    7.1       12.8   11.7        B15
# 175  222.4    3.4       13.1   11.5        B15
# 176  276.9   48.9       41.8   27.0        G15
# 177  248.4   30.2       20.3   20.2        G15
# 178  170.2    7.8       35.2   11.7        B15
# 179  276.7    2.3       23.7   11.8        B15
# 180  165.6   10.0       17.6   12.6        B15
# 181  156.6    2.6        8.3   10.5        B15
# 182  218.5    5.4       27.4   12.2        B15
# 183   56.2    5.7       29.7    8.7        B15
# 184  287.6   43.0       71.8   26.2        G15
# 185  253.8   21.3       30.0   17.6        G15
# 186  205.0   45.1       19.6   22.6        G15
# 187  139.5    2.1       26.6   10.3        B15
# 188  191.1   28.7       18.2   17.3        G15
# 189  286.0   13.9        3.7   15.9        G15
# 190   18.7   12.1       23.4    6.7        B15
# 191   39.5   41.1        5.8   10.8        B15
# 192   75.5   10.8        6.0    9.9        B15
# 193   17.2    4.1       31.6    5.9        B15
# 194  166.8   42.0        3.6   19.6        G15
# 195  149.7   35.6        6.0   17.3        G15
# 196   38.2    3.7       13.8    7.6        B15
# 197   94.2    4.9        8.1    9.7        B15
# 198  177.0    9.3        6.4   12.8        B15
# 199  283.6   42.0       66.2   25.5        G15
# 200  232.1    8.6        8.7   13.4        B15
#
# [200 rows x 5 columns]

# %%
#Check the datatypes
advertising.dtypes
# Out:
# TV            float64
# Radio         float64
# Newspaper     float64
# Sales         float64
# marketType     object
# dtype: object

# %%
#Describes the new dataframe
advertising.describe(include='all')
# Out:
#                 TV       Radio   Newspaper       Sales marketType
# count   200.000000  200.000000  200.000000  200.000000        200
# unique         NaN         NaN         NaN         NaN          2
# top            NaN         NaN         NaN         NaN        B15
# freq           NaN         NaN         NaN         NaN        125
# mean    147.042500   23.264000   30.554000   14.022500        NaN
# std      85.854236   14.846809   21.778621    5.217457        NaN
# min       0.700000    0.000000    0.300000    1.600000        NaN
# 25%      74.375000    9.975000   12.750000   10.375000        NaN
# 50%     149.750000   22.900000   25.750000   12.900000        NaN
# 75%     218.825000   36.525000   45.100000   17.400000        NaN
# max     296.400000   49.600000  114.000000   27.000000        NaN

# %%
#Groups the data by 'marketType and obtains the mean of each column for each group
advertising.groupby('marketType').mean()
# Out:
#                     TV    Radio  Newspaper      Sales
# marketType
# B15         106.927200  16.7888  27.273600  10.669600
# G15         213.901333  34.0560  36.021333  19.610667

# %%
#Groups the data by 'marketType and obtains the mean of each column for each group
advertising.ix[1:200,['Radio','Sales','marketType']].groupby('marketType').std()
# Out:
#                 Radio     Sales
# marketType
# B15         13.553313  2.714603
# G15          9.802926  3.196433

# %%
#Sorts the data by marketType and then Sales in a specified order
advertising.sort_values(by=['marketType','Sales'],ascending=[True,False])
# Out:
#         TV  Radio  Newspaper  Sales marketType
# 27   142.9   29.3       12.6   15.0        B15
# 170  284.3   10.6        6.4   15.0        B15
# 46   175.1   22.5       31.5   14.9        B15
# 163  188.4   18.1       25.6   14.9        B15
# 49   227.2   15.8       49.9   14.8        B15
# 103  280.2   10.1       21.4   14.8        B15
# 38    74.7   49.4       45.7   14.7        B15
# 104  187.9   17.2       17.9   14.7        B15
# 20   147.3   23.9       19.1   14.6        B15
# 115   78.2   46.8       34.5   14.6        B15
# 172  164.5   20.9       47.4   14.5        B15
# 161  172.5   18.1       30.7   14.4        B15
# 78   120.5   28.5       14.2   14.2        B15
# 113  175.7   15.4        2.4   14.1        B15
# 64   102.7   29.6        8.4   14.0        B15
# 84    68.4   44.5       35.6   13.6        B15
# 68   139.3   14.5       10.2   13.4        B15
# 111  225.8    8.2       56.5   13.4        B15
# 200  232.1    8.6        8.7   13.4        B15
# 162   85.7   35.8       49.3   13.3        B15
# 8    120.2   19.6       11.6   13.2        B15
# 58   136.2   19.2       16.6   13.2        B15
# 147  240.1    7.3        8.7   13.2        B15
# 5    180.8   10.8       58.4   12.9        B15
# 44   206.9    8.4       26.4   12.9        B15
# 89    88.3   25.5       73.4   12.9        B15
# 160  131.7   18.4       34.6   12.9        B15
# 36   290.7    4.1        8.5   12.8        B15
# 198  177.0    9.3        6.4   12.8        B15
# 132  265.2    2.9       43.0   12.7        B15
# ..     ...    ...        ...    ...        ...
# 21   218.4   27.7       53.4   18.0        G15
# 65   131.1   42.8       28.9   18.0        G15
# 164  163.5   36.8        7.4   18.0        G15
# 185  253.8   21.3       30.0   17.6        G15
# 12   214.7   24.0        4.0   17.4        G15
# 34   265.6   20.0        0.3   17.4        G15
# 188  191.1   28.7       18.2   17.3        G15
# 195  149.7   35.6        6.0   17.3        G15
# 100  135.2   41.7       45.9   17.2        G15
# 42   177.0   33.4       38.7   17.1        G15
# 169  215.4   23.6       57.6   17.1        G15
# 75   213.4   24.6       13.1   17.0        G15
# 96   163.3   31.6       52.9   16.9        G15
# 90   109.8   47.8       51.4   16.7        G15
# 41   202.5   22.3       31.6   16.6        G15
# 153  197.6   23.3       14.2   16.6        G15
# 151  280.7   13.9       37.0   16.1        G15
# 88   110.7   40.6       63.2   16.0        G15
# 28   240.1   16.7       22.9   15.9        G15
# 114  209.6   20.6       10.7   15.9        G15
# 119  125.7   36.9       79.2   15.9        G15
# 189  286.0   13.9        3.7   15.9        G15
# 63   239.3   15.5       27.3   15.7        G15
# 155  187.8   21.1        9.5   15.6        G15
# 24   228.3   16.9       26.2   15.5        G15
# 98   184.9   21.0       22.0   15.5        G15
# 121  141.3   26.8       46.2   15.5        G15
# 157   93.9   43.5       50.5   15.3        G15
# 86   193.2   18.4       65.7   15.2        G15
# 124  123.1   34.6       12.4   15.2        G15
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Visualization

# %%
#Creates a boxplot of all columns on the dataframe 'data
advertising.boxplot()

# %%
#Creates a boxplot of 'TV' and 'Sales' on the dataframe 'data
advertising.boxplot(column=['TV','Sales'])

# %%
#Creates a boxplot of all columns on the dataframe 'data
advertising.boxplot(column='Sales',by='marketType')

# %%
#Creates a boxplot grouped by 'marketType' (remember that marketType has two possible values)
advertising.groupby('marketType').boxplot()
# Out:
# B15         Axes(0.1,0.15;0.363636x0.75)
# G15    Axes(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
#Creates a histogram of the numerical data on the dataframe
advertising.hist(grid='off')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113c16cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113e7bd30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113e86588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113ecd780>]], dtype=object)

# %%
#Creates a histogram of the numerical data on the dataframe grouped by 'marketType'
advertising.groupby('marketType').hist(column='Radio')
# Out:
# marketType
# B15    [[Axes(0.125,0.125;0.775x0.755)]]
# G15    [[Axes(0.125,0.125;0.775x0.755)]]
# dtype: object

# %%
#Displays the histograms of 'Sales' grouped by 'marketType' in the same plot
plt.rcParams.update({'font.size': 20})
plt.figure()
advertising.groupby('marketType').Sales.hist(alpha=0.5)
plt.legend(labels=['B','G'],loc='best')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.grid('off')

# %%
#Creates a scatter matrix of the numerical data in the dataframe
from pandas.tools.plotting import scatter_matrix
scatter_matrix(advertising, alpha=1, figsize=(10, 10), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114358080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114f49048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114f5c780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11514a2b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x115155ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1151e4668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11522a9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1152817b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1152c99e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11532a320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115374c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11539fbe0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11540e828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11541d3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114739b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1145b36a0>]], dtype=object)

# %% [markdown]
# ## Linear Regression

# %%
#Fit a linear regression model with only one covariate
lrmfit = smf.ols('Sales ~ TV',data=advertising).fit()

# %%
#Displays the outcome of the model fit
print(lrmfit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Thu, 30 Mar 2017   Prob (F-statistic):           1.47e-42
# Time:                        12:41:41   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# TV             0.0475      0.003     17.668      0.000       0.042       0.053
# ==============================================================================
# Omnibus:                        0.531   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.669
# Skew:                          -0.089   Prob(JB):                        0.716
# Kurtosis:                       2.779   Cond. No.                         338.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Creates a scatter plot of 'Sales' as a function of 'TV' and adds the prediction of the model above
plt.figure()
plt.scatter(advertising.TV, advertising.Sales, color='blue')
plt.plot(advertising.TV, lrmfit.predict(), color='red',linewidth=3)
plt.xlabel('TV')
plt.ylabel('Sales')
plt.legend(['Fit','Raw Data'])

# %%
#Create a histogram of the model residuals
plt.hist(lrmfit.resid)
# Out:
# (array([  4.,  10.,  13.,  17.,  40.,  42.,  33.,  16.,  17.,   8.]),
#  array([-8.38598196, -6.82614689, -5.26631183, -3.70647677, -2.14664171,
#         -0.58680664,  0.97302842,  2.53286348,  4.09269854,  5.65253361,
#          7.21236867]),
#  <a list of 10 Patch objects>)

# %%
#Fit a linear regression model with all covariates
mlrmfit = smf.ols('Sales ~ TV + Radio + Newspaper',data=advertising).fit()

# %%
#Displays the outcome of the model
print(mlrmfit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 30 Mar 2017   Prob (F-statistic):           1.58e-96
# Time:                        12:41:49   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# TV             0.0458      0.001     32.809      0.000       0.043       0.049
# Radio          0.1885      0.009     21.893      0.000       0.172       0.206
# Newspaper     -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Obtain the prediction for a new test set
test_TV=100+np.random.randn(10,1)*20
test_Radio=25+np.random.randn(10,1)*10
test_Newspaper=50+np.random.randn(10,1)*10
test_set=np.concatenate((test_TV,test_Radio,test_Newspaper),axis=1)
test_set=pd.DataFrame(test_set,columns=['TV','Radio','Newspaper'])
mlrmfit.predict(test_set)
# Out:
# 0    12.567728
# 1    11.343142
# 2     8.903102
# 3     9.701777
# 4    10.337078
# 5    11.075738
# 6    10.112353
# 7    11.184355
# 8    14.285794
# 9    10.681169
# dtype: float64
